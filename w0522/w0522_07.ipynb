# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'    # windows 한글폰트 연결
# matplotlib.rcParams['font.family'] = 'AppleGothic'      # mac 한글폰트 연결
matplotlib.rcParams['font.size'] = 15                   # 폰트 사이즈
matplotlib.rcParams['axes.unicode_minus'] = False       # 그래프 마이너스(-) 표시

# %%
x = [1, 2, 3]
y = [2, 4, 8]

# %% [markdown]
# 해상도 지정<br>
# plt.figure(dpi=72, 300)<br>

# %%
# x축, y축으로 크기 조정
# plt.figure는 plt.plot 위쪽에 있어야 사이즈 변경됨
# dpi : 파일 저장할때 해상도를 결정 - 파일 크기가 달라짐 (높을수록 크게 저장)
# facecolor : 배경 색을 지정
plt.figure(figsize=(10,5), dpi=72, facecolor='pink')
plt.plot(x, y, label='온도', marker='o', markersize=7)
plt.title('그래프')
plt.legend()
plt.savefig('a2.png', dpi=300)       # plt.plot 아래쪽에 위치해야 함
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(x, y, label='온도', marker='o', markersize=7)
plt.title('그래프')
plt.legend()
plt.show()

# %%
plt.plot(x, y, label='온도', marker='o', markersize=7)
plt.title('그래프')
plt.legend()
# 선 위에 글자를 입력 plt.text()
## text(x축, y축, 데이터 값, 글자위치, 글자색상)
plt.text(x[0], y[0]+0.2, 2, ha='center', color='red')
plt.text(x[1], y[1]+0.2, 4, ha='center', color='red')
plt.text(x[2], y[2]+0.2, 8, ha='center', color='red')
plt.show()
