# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data/score.xlsx', index_col='지원번호')

# %%
df['합계'] = df['국어']+df['영어']+df['수학']

# %%
df['합계'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']

# %%
col = list(df.columns)  # list타입변경
type(col)
# df = df[]
df[[col[-1]]+col[0:-1]]
### list는 list + list 가능
### list str + list 불가
[col[-1]]+col[0:-1]
# Out:
# ['합계', '이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기']

# %%
# 컬럼의 순서를 변경하는 방법법
# df = df[[col[0]]+[col[-1]]+col[1:-1] ]
df.head(1)
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회    SW특기   합계
# 지원번호
# 1번    홍길동  가산고  197  90  85  100  95  85  Python  455

# %%
df = pd.read_excel('data/people.xlsx',skiprows=2,usecols='B:H', index_col='행정기관')
df.columns
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['총인구수', '세대수', '세대당 인구', '남자 인구수', '여자 인구수', '남여 비율'], dtype='object')

# %%
# 1. 컬럼 위치변경
# df = df[['총인구수','남여 비율', '세대수', '세대당 인구', '남자 인구수', '여자 인구수' ]]
col = list(df.columns)
# 2. 컬럼 위치변경
df = df[  [col[0]] + [col[-1]] + col[1:-1] ]
df
# Out:
#                  총인구수      여자 인구수  남여 비율         세대수  세대당 인구      남자 인구수
# 행정기관
# 전국         51,175,725  25,701,092   0.99  24,212,185    2.11  25,474,633
# 서울특별시       9,331,860   4,830,056   0.93   4,498,689    2.07   4,501,804
# 부산광역시       3,256,408   1,672,373   0.95   1,573,173    2.07   1,584,035
# 대구광역시       2,359,159   1,202,546   0.96   1,107,916    2.13   1,156,613
# 인천광역시       3,033,844   1,517,925   1.00   1,385,644    2.19   1,515,919
# 광주광역시       1,400,827     709,493   0.97     658,338    2.13     691,334
# 대전광역시       1,439,393     721,970   0.99     692,420    2.08     717,423
# 울산광역시       1,094,460     530,989   1.06     496,578    2.20     563,471
# 세종특별자치시       391,992     196,891   0.99     164,710    2.38     195,101
# 경기도        13,702,756   6,818,148   1.01   6,084,016    2.25   6,884,608
# 강원특별자치도     1,512,088     751,759   1.01     766,296    1.97     760,329
# 충청북도        1,590,735     780,604   1.04     791,497    2.01     810,131
# ...

# %%
# df = df[['총인구수','남여 비율', '세대수', '세대당 인구', '남자 인구수', '여자 인구수' ]]
# df
